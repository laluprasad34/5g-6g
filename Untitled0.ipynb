# %% [markdown]
# <a href="https://colab.research.google.com/github/laluprasad34/5g-6g/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find-S Algorithm Implementation

# Training data
training_data = [
    (["Sunny", "Warm", "Normal", "Strong", "Warm", "Same"], "Yes"),
        (["Sunny", "Warm", "High", "Strong", "Warm", "Same"], "Yes"),
            (["Rainy", "Cold", "High", "Strong", "Warm", "Change"], "No")
            ]

            # Initialize hypothesis with the first positive example
            hypothesis = None

            for attributes, label in training_data:
                if label == "Yes":
                        if hypothesis is None:
                                    hypothesis = attributes.copy()
                                            else:
                                                        for i in range(len(hypothesis)):
                                                                        if hypothesis[i] != attributes[i]:
                                                                                            hypothesis[i] = "?"

                                                                                            print("Final Hypothesis:", hypothesis)
# Out:
#   File "/tmp/ipython-input-2017802580.py", line 11
#     hypothesis = None
#     ^
# IndentationError: unexpected indent
